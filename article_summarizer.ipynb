# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (3.8.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from spacy) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from spacy) (0.15.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from spacy) (4.66.5)
# Requirement already satisfied: numpy>=1.19.0 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from spacy) (2.8.2)
# Requirement already satisfied: jinja2 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from spacy) (76.1.0)
# Requirement already satisfied: packaging>=20.0 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.2.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: marisa-trie>=1.1.0 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in d:\aiplane_tech2025\anaconda_setup\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.0)
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      - ------------------------------------- 0.5/12.8 MB 479.2 kB/s eta 0:00:26
#      - ------------------------------------- 0.5/12.8 MB 479.2 kB/s eta 0:00:26
#      - ------------------------------------- 0.5/12.8 MB 479.2 kB/s eta 0:00:26
#      -- ------------------------------------ 0.8/12.8 MB 479.7 kB/s eta 0:00:26
#      -- ------------------------------------ 0.8/12.8 MB 479.7 kB/s eta 0:00:26
#      --- ----------------------------------- 1.0/12.8 MB 513.7 kB/s eta 0:00:23
#      --- ----------------------------------- 1.0/12.8 MB 513.7 kB/s eta 0:00:23
#      --- ----------------------------------- 1.0/12.8 MB 513.7 kB/s eta 0:00:23
#      --- ----------------------------------- 1.3/12.8 MB 501.0 kB/s eta 0:00:23
#      --- ----------------------------------- 1.3/12.8 MB 501.0 kB/s eta 0:00:23
#      ---- ---------------------------------- 1.6/12.8 MB 502.4 kB/s eta 0:00:23
#      ---- ---------------------------------- 1.6/12.8 MB 502.4 kB/s eta 0:00:23
#      ---- ---------------------------------- 1.6/12.8 MB 502.4 kB/s eta 0:00:23
#      ----- --------------------------------- 1.8/12.8 MB 505.9 kB/s eta 0:00:22
#      ----- --------------------------------- 1.8/12.8 MB 505.9 kB/s eta 0:00:22
#      ------ -------------------------------- 2.1/12.8 MB 515.2 kB/s eta 0:00:21
#      ------ -------------------------------- 2.1/12.8 MB 515.2 kB/s eta 0:00:21
#      ------- ------------------------------- 2.4/12.8 MB 524.3 kB/s eta 0:00:20
#      ------- ------------------------------- 2.4/12.8 MB 524.3 kB/s eta 0:00:20
#      ------- ------------------------------- 2.6/12.8 MB 524.3 kB/s eta 0:00:20
#      ------- ------------------------------- 2.6/12.8 MB 524.3 kB/s eta 0:00:20
#      -------- ------------------------------ 2.9/12.8 MB 531.0 kB/s eta 0:00:19
#      -------- ------------------------------ 2.9/12.8 MB 531.0 kB/s eta 0:00:19
#      --------- ----------------------------- 3.1/12.8 MB 533.4 kB/s eta 0:00:19
#      --------- ----------------------------- 3.1/12.8 MB 533.4 kB/s eta 0:00:19
#      ---------- ---------------------------- 3.4/12.8 MB 544.1 kB/s eta 0:00:18
#      ---------- ---------------------------- 3.4/12.8 MB 544.1 kB/s eta 0:00:18
#      ----------- --------------------------- 3.7/12.8 MB 549.4 kB/s eta 0:00:17
#      ----------- --------------------------- 3.7/12.8 MB 549.4 kB/s eta 0:00:17
#      ----------- --------------------------- 3.9/12.8 MB 548.8 kB/s eta 0:00:17
#      ----------- --------------------------- 3.9/12.8 MB 548.8 kB/s eta 0:00:17
#      ----------- --------------------------- 3.9/12.8 MB 548.8 kB/s eta 0:00:17
#      ------------ -------------------------- 4.2/12.8 MB 545.9 kB/s eta 0:00:16
#      ------------ -------------------------- 4.2/12.8 MB 545.9 kB/s eta 0:00:16
#      ------------- ------------------------- 4.5/12.8 MB 549.0 kB/s eta 0:00:16
#      ------------- ------------------------- 4.5/12.8 MB 549.0 kB/s eta 0:00:16
#      -------------- ------------------------ 4.7/12.8 MB 552.8 kB/s eta 0:00:15
#      -------------- ------------------------ 4.7/12.8 MB 552.8 kB/s eta 0:00:15
#      --------------- ----------------------- 5.0/12.8 MB 555.1 kB/s eta 0:00:15
#      --------------- ----------------------- 5.0/12.8 MB 555.1 kB/s eta 0:00:15
#      --------------- ----------------------- 5.2/12.8 MB 557.3 kB/s eta 0:00:14
#      --------------- ----------------------- 5.2/12.8 MB 557.3 kB/s eta 0:00:14
#      ---------------- ---------------------- 5.5/12.8 MB 558.3 kB/s eta 0:00:14
#      ---------------- ---------------------- 5.5/12.8 MB 558.3 kB/s eta 0:00:14
#      ---------------- ---------------------- 5.5/12.8 MB 558.3 kB/s eta 0:00:14
#      ----------------- --------------------- 5.8/12.8 MB 555.7 kB/s eta 0:00:13
#      ----------------- --------------------- 5.8/12.8 MB 555.7 kB/s eta 0:00:13
#      ------------------ -------------------- 6.0/12.8 MB 553.4 kB/s eta 0:00:13
#      ------------------ -------------------- 6.0/12.8 MB 553.4 kB/s eta 0:00:13
#      ------------------- ------------------- 6.3/12.8 MB 553.7 kB/s eta 0:00:12
#      ------------------- ------------------- 6.3/12.8 MB 553.7 kB/s eta 0:00:12
#      ------------------- ------------------- 6.6/12.8 MB 553.9 kB/s eta 0:00:12
#      ------------------- ------------------- 6.6/12.8 MB 553.9 kB/s eta 0:00:12
#      ------------------- ------------------- 6.6/12.8 MB 553.9 kB/s eta 0:00:12
#      -------------------- ------------------ 6.8/12.8 MB 554.1 kB/s eta 0:00:11
#      -------------------- ------------------ 6.8/12.8 MB 554.1 kB/s eta 0:00:11
#      -------------------- ------------------ 6.8/12.8 MB 554.1 kB/s eta 0:00:11
#      --------------------- ----------------- 7.1/12.8 MB 548.0 kB/s eta 0:00:11
#      --------------------- ----------------- 7.1/12.8 MB 548.0 kB/s eta 0:00:11
#      ---------------------- ---------------- 7.3/12.8 MB 549.1 kB/s eta 0:00:10
#      ---------------------- ---------------- 7.3/12.8 MB 549.1 kB/s eta 0:00:10
#      ----------------------- --------------- 7.6/12.8 MB 550.7 kB/s eta 0:00:10
#      ----------------------- --------------- 7.6/12.8 MB 550.7 kB/s eta 0:00:10
#      ----------------------- --------------- 7.9/12.8 MB 553.5 kB/s eta 0:00:09
#      ----------------------- --------------- 7.9/12.8 MB 553.5 kB/s eta 0:00:09
#      ------------------------ -------------- 8.1/12.8 MB 554.3 kB/s eta 0:00:09
#      ------------------------ -------------- 8.1/12.8 MB 554.3 kB/s eta 0:00:09
#      ------------------------- ------------- 8.4/12.8 MB 552.7 kB/s eta 0:00:08
#      ------------------------- ------------- 8.4/12.8 MB 552.7 kB/s eta 0:00:08
#      -------------------------- ------------ 8.7/12.8 MB 554.1 kB/s eta 0:00:08
#      -------------------------- ------------ 8.7/12.8 MB 554.1 kB/s eta 0:00:08
#      --------------------------- ----------- 8.9/12.8 MB 555.3 kB/s eta 0:00:08
#      --------------------------- ----------- 8.9/12.8 MB 555.3 kB/s eta 0:00:08
#      --------------------------- ----------- 9.2/12.8 MB 555.4 kB/s eta 0:00:07
#      --------------------------- ----------- 9.2/12.8 MB 555.4 kB/s eta 0:00:07
#      --------------------------- ----------- 9.2/12.8 MB 555.4 kB/s eta 0:00:07
#      ---------------------------- ---------- 9.4/12.8 MB 556.1 kB/s eta 0:00:07
#      ---------------------------- ---------- 9.4/12.8 MB 556.1 kB/s eta 0:00:07
#      ----------------------------- --------- 9.7/12.8 MB 557.2 kB/s eta 0:00:06
#      ----------------------------- --------- 9.7/12.8 MB 557.2 kB/s eta 0:00:06
#      ----------------------------- -------- 10.0/12.8 MB 557.2 kB/s eta 0:00:06
#      ----------------------------- -------- 10.0/12.8 MB 557.2 kB/s eta 0:00:06
#      ------------------------------ ------- 10.2/12.8 MB 559.7 kB/s eta 0:00:05
#      ------------------------------ ------- 10.2/12.8 MB 559.7 kB/s eta 0:00:05
#      ------------------------------ ------- 10.2/12.8 MB 559.7 kB/s eta 0:00:05
#      ------------------------------- ------ 10.5/12.8 MB 551.7 kB/s eta 0:00:05
#      ------------------------------- ------ 10.5/12.8 MB 551.7 kB/s eta 0:00:05
#      ------------------------------- ------ 10.5/12.8 MB 551.7 kB/s eta 0:00:05
#      ------------------------------- ------ 10.7/12.8 MB 550.1 kB/s eta 0:00:04
#      ------------------------------- ------ 10.7/12.8 MB 550.1 kB/s eta 0:00:04
#      -------------------------------- ----- 11.0/12.8 MB 548.1 kB/s eta 0:00:04
#      -------------------------------- ----- 11.0/12.8 MB 548.1 kB/s eta 0:00:04
#      -------------------------------- ----- 11.0/12.8 MB 548.1 kB/s eta 0:00:04
#      --------------------------------- ---- 11.3/12.8 MB 548.4 kB/s eta 0:00:03
#      --------------------------------- ---- 11.3/12.8 MB 548.4 kB/s eta 0:00:03
#      ---------------------------------- --- 11.5/12.8 MB 547.0 kB/s eta 0:00:03
#      ---------------------------------- --- 11.5/12.8 MB 547.0 kB/s eta 0:00:03
#      ----------------------------------- -- 11.8/12.8 MB 546.8 kB/s eta 0:00:02
#      ----------------------------------- -- 11.8/12.8 MB 546.8 kB/s eta 0:00:02
#      ----------------------------------- -- 11.8/12.8 MB 546.8 kB/s eta 0:00:02
#      ----------------------------------- -- 12.1/12.8 MB 546.7 kB/s eta 0:00:02
#      ----------------------------------- -- 12.1/12.8 MB 546.7 kB/s eta 0:00:02
#      ------------------------------------ - 12.3/12.8 MB 547.0 kB/s eta 0:00:01
#      ------------------------------------ - 12.3/12.8 MB 547.0 kB/s eta 0:00:01
#      ------------------------------------ - 12.3/12.8 MB 547.0 kB/s eta 0:00:01
#      ------------------------------------ - 12.3/12.8 MB 547.0 kB/s eta 0:00:01
#      -------------------------------------  12.6/12.8 MB 538.3 kB/s eta 0:00:01
#      -------------------------------------  12.6/12.8 MB 538.3 kB/s eta 0:00:01
#      -------------------------------------- 12.8/12.8 MB 534.9 kB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
from heapq import nlargest

# Load spaCy English nlp model
nlp = spacy.load("en_core_web_sm")

def summarize(text,ratio=0.3):

    # Process the Text with spaCy
    doc = nlp(text)
    sentences = list(doc.sents)

    # Compute word frequency (ignoring stopwords & punctuation)
    word_freq = {}
    for word in doc:
        if not word.is_stop and not word.is_punct:
            word_freq[word.text.lower()] = word_freq.get(word.text.lower(), 0) + 1

    # Score sentences based on word frequencies
    sentence_scores = {sent: sum(word_freq.get(word.text.lower(), 0) for word in sent) for sent in sentences}

    # Select top sentences based on the ratio
    num_sentences = max(1, int(len(sentences) * ratio))
    summary_sentences = nlargest(num_sentences, sentence_scores, key=sentence_scores.get)

    return " ".join(sent.text for sent in summary_sentences)

# Example Usage
article =""""
        The Road to Success: A Journey of Perseverance and Growth
Success is not an overnight achievement but a journey of dedication, hard work, and continuous learning.
It begins with a clear vision and the determination to overcome obstacles. Setting realistic goals and maintaining discipline helps in staying focused.
Challenges and failures are inevitable, but they serve as stepping stones toward growth.
A positive mindset and self-confidence play a crucial role in pushing forward despite difficulties.
Learning from mistakes and adapting to changes improve resilience. Surrounding oneself with like-minded, motivated individuals fosters inspiration and encouragement.
Time management and consistency are key factors in achieving long-term goals. Developing skills, gaining knowledge,and staying updated with industry trends enhance personal and professional growth.
Passion fuels persistence, making hard work enjoyable rather than a burden. Overcoming self-doubt and believing in one’s abilities create a strong foundation for success.
Taking calculated risks opens new opportunities and broadens perspectives. Maintaining a healthy work-life balance ensures sustainable progress.
Helping others and sharing knowledge bring fulfillment and contribute to overall success. Embracing failure as a lesson rather than a setback strengthens determination.
A growth-oriented mindset leads to continuous improvement and innovation. Seeking mentorship from experienced individuals accelerates learning and avoids common pitfalls.
Financial discipline and smart investments secure stability and future success. Accepting constructive criticism and working on self-improvement lead to personal excellence.
Staying humble despite achievements keeps one grounded and open to new learning experiences. Gratitude and appreciation for small victories.
         """
summary = summarize(article) 

print("Summary:\n", summary)
# Out:
# Summary:
#  "
#         The Road to Success: A Journey of Perseverance and Growth
# Success is not an overnight achievement but a journey of dedication, hard work, and continuous learning.
#  Developing skills, gaining knowledge,and staying updated with industry trends enhance personal and professional growth.
#  A positive mindset and self-confidence play a crucial role in pushing forward despite difficulties.
#  Overcoming self-doubt and believing in one’s abilities create a strong foundation for success.
#  Setting realistic goals and maintaining discipline helps in staying focused.
#  Seeking mentorship from experienced individuals accelerates learning and avoids common pitfalls.
